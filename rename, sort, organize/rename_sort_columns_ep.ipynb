# %%
import pandas as pd

# %%
df = pd.read_csv("email_phone_latest.csv")

# %%
df
# Out:
#          Unnamed: 0        full_name
# 0                 0  jeff raudebaugh  \
# 1                 1  yashoda sampath
# 2                 2  christina wiech
# 3                 3  heather shields
# 4                 4  gary willoughby
# ...             ...              ...
# 3748877     3748877  christina duong
# 3748878     3748878    kelly gelling
# 3748879     3748879      lisa gillis
# 3748880     3748880    yvonne ceresa
# 3748881     3748881  tanita thompson
#
#                                       linkedin_url
# 0         linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1          linkedin.com/in/yashoda-sampath-4322064
# 2                   linkedin.com/in/christinawiech
# 3        linkedin.com/in/heather-shields-6797b711b
# 4         linkedin.com/in/gary-willoughby-4460036b
# ...                                            ...
# 3748877   linkedin.com/in/christina-duong-5b321515
# 3748878     linkedin.com/in/kelly-gelling-53230223
# ...

# %%
df.drop(columns='emails')
# Out:
#          Unnamed: 0        full_name
# 0                 0  jeff raudebaugh  \
# 1                 1  yashoda sampath
# 2                 2  christina wiech
# 3                 3  heather shields
# 4                 4  gary willoughby
# ...             ...              ...
# 3748877     3748877  christina duong
# 3748878     3748878    kelly gelling
# 3748879     3748879      lisa gillis
# 3748880     3748880    yvonne ceresa
# 3748881     3748881  tanita thompson
#
#                                       linkedin_url
# 0         linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1          linkedin.com/in/yashoda-sampath-4322064
# 2                   linkedin.com/in/christinawiech
# 3        linkedin.com/in/heather-shields-6797b711b
# 4         linkedin.com/in/gary-willoughby-4460036b
# ...                                            ...
# 3748877   linkedin.com/in/christina-duong-5b321515
# 3748878     linkedin.com/in/kelly-gelling-53230223
# ...

# %%
df1 = df[['full_name', 'linkedin_url', 'phone_numbers', 'Personal_Email', 'location_name' ]]

# %%
df1
# Out:
#                full_name                               linkedin_url
# 0        jeff raudebaugh   linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1        yashoda sampath    linkedin.com/in/yashoda-sampath-4322064
# 2        christina wiech             linkedin.com/in/christinawiech
# 3        heather shields  linkedin.com/in/heather-shields-6797b711b
# 4        gary willoughby   linkedin.com/in/gary-willoughby-4460036b
# ...                  ...                                        ...
# 3748877  christina duong   linkedin.com/in/christina-duong-5b321515
# 3748878    kelly gelling     linkedin.com/in/kelly-gelling-53230223
# 3748879      lisa gillis       linkedin.com/in/lisa-gillis-44248024
# 3748880    yvonne ceresa               linkedin.com/in/yvonneceresa
# 3748881  tanita thompson             linkedin.com/in/tanitathompson
#
#                                              phone_numbers
# 0                         ['+17035355810', '+18105777866']  \
# ...

# %%
df2 = df1.rename(columns = {'Personal_Email': 'emails'})

# %%
df1.to_csv("email_phone_final.csv")

# %%
df2 = df1.rename(columns={'location_name': 'location', 'Personal_Email': 'emails'})

# %%
df2
# Out:
#                full_name                               linkedin_url
# 0        jeff raudebaugh   linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1        yashoda sampath    linkedin.com/in/yashoda-sampath-4322064
# 2        christina wiech             linkedin.com/in/christinawiech
# 3        heather shields  linkedin.com/in/heather-shields-6797b711b
# 4        gary willoughby   linkedin.com/in/gary-willoughby-4460036b
# ...                  ...                                        ...
# 3748877  christina duong   linkedin.com/in/christina-duong-5b321515
# 3748878    kelly gelling     linkedin.com/in/kelly-gelling-53230223
# 3748879      lisa gillis       linkedin.com/in/lisa-gillis-44248024
# 3748880    yvonne ceresa               linkedin.com/in/yvonneceresa
# 3748881  tanita thompson             linkedin.com/in/tanitathompson
#
#                                              phone_numbers
# 0                         ['+17035355810', '+18105777866']  \
# ...

# %%
df2.to_csv("file.csv")
