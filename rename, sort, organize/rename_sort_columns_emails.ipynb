# %%
import pandas as pd

# %%
df = pd.read_csv("pers_email_latest.csv")

# %%
df
# Out:
#          Unnamed: 0                full_name
# 0                 0           victoria ryder  \
# 1                 1      christophe esposito
# 2                 2              wenzhong wu
# 3                 3          matthew erskine
# 4                 4  kishore chakravadhanula
# ...             ...                      ...
# 5884465     5884465           matthew stasik
# 5884466     5884466              donna elrod
# 5884467     5884467             amy jennette
# 5884468     5884468                sara kuhn
# 5884469     5884469             paul accardi
#
#                                      linkedin_url phone_numbers
# 0          linkedin.com/in/victoria-ryder-a504329            []  \
# 1              linkedin.com/in/christopheesposito            []
# 2            linkedin.com/in/wenzhong-wu-85b8b126            []
# 3        linkedin.com/in/matthew-erskine-97159844            []
# 4                        linkedin.com/in/kchakrav            []
# ...

# %%
df1 = df.drop(columns='emails')

# %%
df1
# Out:
#          Unnamed: 0                full_name
# 0                 0           victoria ryder  \
# 1                 1      christophe esposito
# 2                 2              wenzhong wu
# 3                 3          matthew erskine
# 4                 4  kishore chakravadhanula
# ...             ...                      ...
# 5884465     5884465           matthew stasik
# 5884466     5884466              donna elrod
# 5884467     5884467             amy jennette
# 5884468     5884468                sara kuhn
# 5884469     5884469             paul accardi
#
#                                      linkedin_url phone_numbers
# 0          linkedin.com/in/victoria-ryder-a504329            []  \
# 1              linkedin.com/in/christopheesposito            []
# 2            linkedin.com/in/wenzhong-wu-85b8b126            []
# 3        linkedin.com/in/matthew-erskine-97159844            []
# 4                        linkedin.com/in/kchakrav            []
# ...

# %%
df2 = df1.rename(columns={'Personal_Email': 'emails', 'location_name': 'location'})

# %%
df2
# Out:
#          Unnamed: 0                full_name
# 0                 0           victoria ryder  \
# 1                 1      christophe esposito
# 2                 2              wenzhong wu
# 3                 3          matthew erskine
# 4                 4  kishore chakravadhanula
# ...             ...                      ...
# 5884465     5884465           matthew stasik
# 5884466     5884466              donna elrod
# 5884467     5884467             amy jennette
# 5884468     5884468                sara kuhn
# 5884469     5884469             paul accardi
#
#                                      linkedin_url phone_numbers
# 0          linkedin.com/in/victoria-ryder-a504329            []  \
# 1              linkedin.com/in/christopheesposito            []
# 2            linkedin.com/in/wenzhong-wu-85b8b126            []
# 3        linkedin.com/in/matthew-erskine-97159844            []
# 4                        linkedin.com/in/kchakrav            []
# ...

# %%
df3 = df2[['full_name', 'linkedin_url', 'phone_numbers', 'emails', 'location' ]]

# %%
df3
# Out:
#                        full_name                              linkedin_url
# 0                 victoria ryder    linkedin.com/in/victoria-ryder-a504329  \
# 1            christophe esposito        linkedin.com/in/christopheesposito
# 2                    wenzhong wu      linkedin.com/in/wenzhong-wu-85b8b126
# 3                matthew erskine  linkedin.com/in/matthew-erskine-97159844
# 4        kishore chakravadhanula                  linkedin.com/in/kchakrav
# ...                          ...                                       ...
# 5884465           matthew stasik   linkedin.com/in/matthew-stasik-89436330
# 5884466              donna elrod       linkedin.com/in/donna-elrod-3b06448
# 5884467             amy jennette               linkedin.com/in/amyjennette
# 5884468                sara kuhn        linkedin.com/in/sara-kuhn-79478036
# 5884469             paul accardi     linkedin.com/in/paul-accardi-35a6b337
#
# ...

# %%
df3.to_csv("file.csv")
