# %%
import pandas as pd

# %%
df = pd.read_csv("linked.csv")

# %%
df
# Out:
#                   full_name                                 linkedin_url
# 0             mark buchanan        linkedin.com/in/mark-buchanan-62a13ba  \
# 1         christine bingham   linkedin.com/in/christine-bingham-76057a2a
# 2          paul rainsberger     linkedin.com/in/paul-rainsberger-7217214
# 3        leslie van calster  linkedin.com/in/leslie-van-calster-4b02b017
# 4               adan monroy         linkedin.com/in/adan-monroy-45100534
# ...                     ...                                          ...
# 5919405       james talmich       linkedin.com/in/james-talmich-887b4713
# 5919406    zachary salzbank                    linkedin.com/in/zsalzbank
# 5919407     srikanth kakani                     linkedin.com/in/srikantk
# 5919408        van andy dam         linkedin.com/in/andy-dam-van-aa5676b
# 5919409     shirley barnett     linkedin.com/in/shirley-barnett-265b852b
#
#         phone_numbers                                             emails
# ...

# %%
df1 = df.drop_duplicates(subset='linkedin_url', keep='first')

# %%
df1
# Out:
#                   full_name                                 linkedin_url
# 0             mark buchanan        linkedin.com/in/mark-buchanan-62a13ba  \
# 1         christine bingham   linkedin.com/in/christine-bingham-76057a2a
# 2          paul rainsberger     linkedin.com/in/paul-rainsberger-7217214
# 3        leslie van calster  linkedin.com/in/leslie-van-calster-4b02b017
# 4               adan monroy         linkedin.com/in/adan-monroy-45100534
# ...                     ...                                          ...
# 5919405       james talmich       linkedin.com/in/james-talmich-887b4713
# 5919406    zachary salzbank                    linkedin.com/in/zsalzbank
# 5919407     srikanth kakani                     linkedin.com/in/srikantk
# 5919408        van andy dam         linkedin.com/in/andy-dam-van-aa5676b
# 5919409     shirley barnett     linkedin.com/in/shirley-barnett-265b852b
#
#         phone_numbers                                             emails
# ...

# %%
df1.to_csv("mainfile.csv", index=False)

# %%
df1
# Out:
#                   full_name                                 linkedin_url
# 0             mark buchanan        linkedin.com/in/mark-buchanan-62a13ba  \
# 1         christine bingham   linkedin.com/in/christine-bingham-76057a2a
# 2          paul rainsberger     linkedin.com/in/paul-rainsberger-7217214
# 3        leslie van calster  linkedin.com/in/leslie-van-calster-4b02b017
# 4               adan monroy         linkedin.com/in/adan-monroy-45100534
# ...                     ...                                          ...
# 5919405       james talmich       linkedin.com/in/james-talmich-887b4713
# 5919406    zachary salzbank                    linkedin.com/in/zsalzbank
# 5919407     srikanth kakani                     linkedin.com/in/srikantk
# 5919408        van andy dam         linkedin.com/in/andy-dam-van-aa5676b
# 5919409     shirley barnett     linkedin.com/in/shirley-barnett-265b852b
#
#         phone_numbers                                             emails
# ...
