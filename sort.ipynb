# %%
import pandas as pd

# %%
df = pd.read_csv("email_phone_latest.csv")

# %%
df
# Out:
#                full_name                               linkedin_url
# 0        jeff raudebaugh   linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1        yashoda sampath    linkedin.com/in/yashoda-sampath-4322064
# 2        christina wiech             linkedin.com/in/christinawiech
# 3        heather shields  linkedin.com/in/heather-shields-6797b711b
# 4        gary willoughby   linkedin.com/in/gary-willoughby-4460036b
# ...                  ...                                        ...
# 1048570        nick chen              linkedin.com/in/nicholasychen
# 1048571     carolyn dove       linkedin.com/in/carolyn-dove-4346a94
# 1048572     susan paglia       linkedin.com/in/susan-paglia-4897009
# 1048573  michele starkey   linkedin.com/in/michele-starkey-166b2210
# 1048574  lonnie thompson             linkedin.com/in/lonniethompson
#
#                                              phone_numbers
# 0                         ['+17035355810', '+18105777866']  \
# ...

# %%
df1 = df[['full_name', 'linkedin_url','phone_numbers', 'emails', 'location_name' ]]

# %%
df1
# Out:
#                full_name                               linkedin_url
# 0        jeff raudebaugh   linkedin.com/in/jeff-raudebaugh-816a8028  \
# 1        yashoda sampath    linkedin.com/in/yashoda-sampath-4322064
# 2        christina wiech             linkedin.com/in/christinawiech
# 3        heather shields  linkedin.com/in/heather-shields-6797b711b
# 4        gary willoughby   linkedin.com/in/gary-willoughby-4460036b
# ...                  ...                                        ...
# 1048570        nick chen              linkedin.com/in/nicholasychen
# 1048571     carolyn dove       linkedin.com/in/carolyn-dove-4346a94
# 1048572     susan paglia       linkedin.com/in/susan-paglia-4897009
# 1048573  michele starkey   linkedin.com/in/michele-starkey-166b2210
# 1048574  lonnie thompson             linkedin.com/in/lonniethompson
#
#                                              phone_numbers
# 0                         ['+17035355810', '+18105777866']  \
# ...

# %%
df1.to_csv("email_phone_new.csv")
