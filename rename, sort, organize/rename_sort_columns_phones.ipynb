# %%
import pandas as pd

# %%
df = pd.read_csv("phone_only.csv")

# %%
df
# Out:
#                      full_name
# 0              anna meyendorff  \
# 1                karen kennard
# 2                   carson woś
# 3             mallory marcotte
# 4                  max masters
# ...                        ...
# 4312839              dave naab
# 4312840            jeff heiney
# 4312841  cynthia lugo-anatello
# 4312842           pao-gen wang
# 4312843          chip rominger
#
#                                            linkedin_url     phone_numbers
# 0              linkedin.com/in/anna-meyendorff-2191068a  ['+12024086110']  \
# 1                linkedin.com/in/karen-kennard-9b5aa623  ['+14358826482']
# 2                             linkedin.com/in/carsonwos  ['+19142202512']
# 3                       linkedin.com/in/mallorymarcotte  ['+17862791057']
# 4                  linkedin.com/in/max-masters-bb43a742  ['+16056393167']
# ...                                                 ...               ...
# ...

# %%
df2 = df[['full_name', 'linkedin_url', 'phone_numbers', 'emails', 'location_name' ]]

# %%
df2
# Out:
#                      full_name
# 0              anna meyendorff  \
# 1                karen kennard
# 2                   carson woś
# 3             mallory marcotte
# 4                  max masters
# ...                        ...
# 4312839              dave naab
# 4312840            jeff heiney
# 4312841  cynthia lugo-anatello
# 4312842           pao-gen wang
# 4312843          chip rominger
#
#                                            linkedin_url     phone_numbers
# 0              linkedin.com/in/anna-meyendorff-2191068a  ['+12024086110']  \
# 1                linkedin.com/in/karen-kennard-9b5aa623  ['+14358826482']
# 2                             linkedin.com/in/carsonwos  ['+19142202512']
# 3                       linkedin.com/in/mallorymarcotte  ['+17862791057']
# 4                  linkedin.com/in/max-masters-bb43a742  ['+16056393167']
# ...                                                 ...               ...
# ...

# %%
df1 = df2.rename(columns={'location_name':'location'})

# %%
df1
# Out:
#                      full_name
# 0              anna meyendorff  \
# 1                karen kennard
# 2                   carson woś
# 3             mallory marcotte
# 4                  max masters
# ...                        ...
# 4312839              dave naab
# 4312840            jeff heiney
# 4312841  cynthia lugo-anatello
# 4312842           pao-gen wang
# 4312843          chip rominger
#
#                                            linkedin_url     phone_numbers
# 0              linkedin.com/in/anna-meyendorff-2191068a  ['+12024086110']  \
# 1                linkedin.com/in/karen-kennard-9b5aa623  ['+14358826482']
# 2                             linkedin.com/in/carsonwos  ['+19142202512']
# 3                       linkedin.com/in/mallorymarcotte  ['+17862791057']
# 4                  linkedin.com/in/max-masters-bb43a742  ['+16056393167']
# ...                                                 ...               ...
# ...

# %%
df1.to_csv("phone.csv")
